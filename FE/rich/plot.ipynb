# %%
from dfe import *

# %%
plot_multiple_formation_E("unrelaxed_rich.in", case="Zn-rich", xval=[1.4, 1.5, 0.15, 0.5, 1.2, 0.25, 1.5 ])
# Out:
# Adding the following to the plot: Co_vac_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Cu_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Co_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Fe_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Ni_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Fe_vac_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Cu_vac_unrelaxed_ZnRich.in_out

# %%
plot_multiple_formation_E("relaxed_rich.in", case="Zn-rich", xval=[1.4, 0.5, 0.15, 1, 1.5, 0.25, 1.1 ])
# Out:
# Adding the following to the plot: Cu_relaxed_ZnRich.in_out
#
# Adding the following to the plot: Co_relaxed_ZnRich.in_out
#
# Adding the following to the plot: Fe_relaxed_ZnRich.in_out
#
# Adding the following to the plot: Ni_relaxed_ZnRich.in_out
#
# Adding the following to the plot: Cu_vac_relaxed_ZnRich.in_out
#
# Adding the following to the plot: Co_vac_relaxed_ZnRich.in_out
#
# Adding the following to the plot: Fe_vac_relaxed_ZnRich.in_out

# %%
plot_multiple_formation_E("relaxed_impurity.in", case="Zn-rich, relaxed")
# Out:
# Adding the following to the plot: Cu_relaxed_ZnRich.in_out
#
# Adding the following to the plot: Co_relaxed_ZnRich.in_out
#
# Adding the following to the plot: Fe_relaxed_ZnRich.in_out
#
# Adding the following to the plot: Ni_relaxed_ZnRich.in_out

# %%
plot_multiple_formation_E("unrelaxed_impurity.in", case="Zn-rich, unrelaxed")
# Out:
# Adding the following to the plot: Cu_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Co_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Fe_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Ni_unrelaxed_ZnRich.in_out
