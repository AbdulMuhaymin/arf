# %%
from dfe import *

# %%
plot_multiple_formation_E("unrelaxed_poor.in", case="Zn-poor", xval=[1.5, 0.3, 0.15, 1.0, 1.5, 0.25, 1.1 ])
# Out:
# Adding the following to the plot: Cu_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Co_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Fe_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Ni_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Cu_vac_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Co_vac_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Fe_vac_unrelaxed_ZnPoor.in_out

# %%
plot_multiple_formation_E("relaxed_poor.in", case="Zn-poor", xval=[1.1, 0.35, 0.2, 1.0, 1.1, 0.25, 1.1 ])
# Out:
# Adding the following to the plot: Cu_relaxed_ZnPoor.in_out
#
# Adding the following to the plot: Co_relaxed_ZnPoor.in_out
#
# Adding the following to the plot: Fe_relaxed_ZnPoor.in_out
#
# Adding the following to the plot: Ni_relaxed_ZnPoor.in_out
#
# Adding the following to the plot: Cu_vac_relaxed_ZnPoor.in_out
#
# Adding the following to the plot: Co_vac_relaxed_ZnPoor.in_out
#
# Adding the following to the plot: Fe_vac_relaxed_ZnPoor.in_out
