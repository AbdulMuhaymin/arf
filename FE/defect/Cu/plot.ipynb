# %%
from dfe import *

# %%
calculate_E_formation('Cu_unrelaxed_ZnRich.in')
calculate_E_formation('Cu_unrelaxed_ZnPoor.in')
calculate_E_formation('Cu_relaxed_ZnRich.in')
calculate_E_formation('Cu_relaxed_ZnPoor.in')
# Out:
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6622.094621374602
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 2.3590497253981084
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6622.567933108981
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 1.8857379910186864
#
# CTL from 0 to -1 = 0.475
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6622.794621374602
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 1.6590497253982903
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6623.26793310898
#
# chem_potential for Cu (impurity)  has been added.
# ...

# %%
plot_multiple_formation_E("Cu_ZnPoor.in", case="Zn-poor")
# Out:
# Adding the following to the plot: Cu_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Cu_relaxed_ZnPoor.in_out

# %%
plot_multiple_formation_E("Cu_ZnRich.in", case="Zn-rich")
# Out:
# Adding the following to the plot: Cu_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Cu_relaxed_ZnRich.in_out
