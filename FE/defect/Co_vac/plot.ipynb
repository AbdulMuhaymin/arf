# %%
from dfe import *

# %%
calculate_E_formation('Co_vac_unrelaxed_ZnRich.in')
calculate_E_formation('Co_vac_unrelaxed_ZnPoor.in')
calculate_E_formation('Co_vac_relaxed_ZnRich.in')
calculate_E_formation('Co_vac_relaxed_ZnPoor.in')
# Out:
# charge_state =-2
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4213.660711261897
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5114.728826381896
#
# chem_potential for Co (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 10.915433318103169
#
#
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4216.442444430354
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5117.510559550354
#
# chem_potential for Co (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 8.133700149645847
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4218.157307124933
#
# chem_potential for S (vacancy)  has been added.
#
# ...

# %%
plot_multiple_formation_E("Co_vac_ZnPoor.in", case="Zn-poor")
# Out:
# Adding the following to the plot: Co_vac_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Co_vac_relaxed_ZnPoor.in_out

# %%
plot_multiple_formation_E("Co_vac_ZnRich.in", case="Zn-rich")
# Out:
# Adding the following to the plot: Co_vac_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Co_vac_relaxed_ZnRich.in_out
