# %%
from dfe import *

# %%
calculate_E_formation('Ni_unrelaxed_ZnRich.in')
calculate_E_formation('Ni_unrelaxed_ZnPoor.in')
calculate_E_formation('Ni_relaxed_ZnRich.in')
calculate_E_formation('Ni_relaxed_ZnPoor.in')
# Out:
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5835.8214666770755
#
# chem_potential for Ni (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 3.2618679229244663
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5837.103415708352
#
# chem_potential for Ni (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 1.979918891647685
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5837.482740819014
#
# chem_potential for Ni (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 1.600593780985946
#
# CTL from 1 to 0 = 0.385
#
# CTL from 0 to -1 = 1.2850000000000001
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5836.521466677075
#
# ...

# %%
plot_multiple_formation_E("Ni_ZnPoor.in", case="Zn-poor")
# Out:
# Adding the following to the plot: Ni_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Ni_relaxed_ZnPoor.in_out

# %%
plot_multiple_formation_E("Ni_ZnRich.in", case="Zn-rich")
# Out:
# Adding the following to the plot: Ni_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Ni_relaxed_ZnRich.in_out
