# %%
from dfe import *

# %%
calculate_E_formation('Cu_vac_unrelaxed_ZnRich.in')
calculate_E_formation('Cu_vac_unrelaxed_ZnPoor.in')
calculate_E_formation('Cu_vac_relaxed_ZnRich.in')
calculate_E_formation('Cu_vac_relaxed_ZnPoor.in')
# Out:
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5716.360428139752
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6617.428543259752
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 7.025127840248388
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5717.646438334024
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6618.714553454024
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 5.739117645975966
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5718.285876247999
#
# chem_potential for S (vacancy)  has been added.
#
# ...

# %%
plot_multiple_formation_E("Cu_vac_ZnPoor.in", case="Zn-poor")
# Out:
# Adding the following to the plot: Cu_vac_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Cu_vac_relaxed_ZnPoor.in_out

# %%
plot_multiple_formation_E("Cu_vac_ZnRich.in", case="Zn-rich")
# Out:
# Adding the following to the plot: Cu_vac_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Cu_vac_relaxed_ZnRich.in_out
