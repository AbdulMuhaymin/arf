# %%
from dfe import *

# %%
calculate_E_formation('Fe_vac_unrelaxed_ZnRich.in')
calculate_E_formation('Fe_vac_unrelaxed_ZnPoor.in')
calculate_E_formation('Fe_vac_relaxed_ZnRich.in')
calculate_E_formation('Fe_vac_relaxed_ZnPoor.in')
# Out:
# charge_state =-2
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -3568.16001675495
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4469.22813187495
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 10.727581125050165
#
#
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -3570.742107754263
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4471.810222874263
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 8.145490125737524
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -3572.4181983083286
#
# chem_potential for S (vacancy)  has been added.
#
# ...

# %%
plot_multiple_formation_E("Fe_vac_ZnPoor.in", case="Zn-poor")
# Out:
# Adding the following to the plot: Fe_vac_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Fe_vac_relaxed_ZnPoor.in_out

# %%
plot_multiple_formation_E("Fe_vac_ZnRich.in", case="Zn-rich")
# Out:
# Adding the following to the plot: Fe_vac_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Fe_vac_relaxed_ZnRich.in_out
