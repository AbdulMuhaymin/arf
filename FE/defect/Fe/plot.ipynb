# %%
from dfe import *

# %%
calculate_E_formation('Fe_unrelaxed_ZnRich.in')
calculate_E_formation('Fe_unrelaxed_ZnPoor.in')
calculate_E_formation('Fe_relaxed_ZnRich.in')
calculate_E_formation('Fe_relaxed_ZnPoor.in')
# Out:
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4476.582248648755
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 3.373464351245275
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4478.471648969924
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 1.484064030076297
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4479.15806788261
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 0.7976451173899477
#
# CTL from 1 to 0 = 0.6950000000000001
#
# CTL from 0 to -1 = 1.895
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4477.282248648755
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 2.673464351245457
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4479.171648969923
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 0.7840640300773885
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4479.85806788261
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 0.0976451173901296
#
# CTL from 1 to 0 = 0.6950000000000001
#
# CTL from 0 to -1 = 1.895
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4476.675651996465
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 3.280061003535593
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4478.4803039587605
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 1.4754090412398
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4479.296230011325
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 0.659482988675336
#
# CTL from 1 to 0 = 0.8250000000000001
#
# CTL from 0 to -1 = 1.8050000000000002
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4477.3756519964645
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 2.580061003535775
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4479.180303958759
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 0.7754090412408914
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -4479.996230011325
#
# chem_potential for Fe (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -0.040517011324482155
#
# CTL from 1 to 0 = 0.8250000000000001
#
# CTL from 0 to -1 = 1.8050000000000002

# %%
plot_multiple_formation_E("Fe_ZnPoor.in", case="Zn-poor")
# Out:
# Adding the following to the plot: Fe_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Fe_relaxed_ZnPoor.in_out

# %%
plot_multiple_formation_E("Fe_ZnRich.in", case="Zn-rich")
# Out:
# Adding the following to the plot: Fe_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Fe_relaxed_ZnRich.in_out
