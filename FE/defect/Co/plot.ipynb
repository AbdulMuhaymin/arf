# %%
from dfe import *

# %%
calculate_E_formation('Co_unrelaxed_ZnRich.in')
calculate_E_formation('Co_unrelaxed_ZnPoor.in')
calculate_E_formation('Co_relaxed_ZnRich.in')
calculate_E_formation('Co_relaxed_ZnPoor.in')
# Out:
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5122.004016457863
#
# chem_potential for Co (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 3.640243242136421
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5124.095617716757
#
# chem_potential for Co (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 1.5486419832423053
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5124.182202691616
#
# chem_potential for Co (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 1.4620570083834536
#
# CTL from 1 to 0 = 0.095
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5122.704016457863
#
# chem_potential for Co (impurity)  has been added.
# ...

# %%
plot_multiple_formation_E("Co_ZnPoor.in", case="Zn-poor")
# Out:
# Adding the following to the plot: Co_unrelaxed_ZnPoor.in_out
#
# Adding the following to the plot: Co_relaxed_ZnPoor.in_out

# %%
plot_multiple_formation_E("Co_ZnRich.in", case="Zn-rich")
# Out:
# Adding the following to the plot: Co_unrelaxed_ZnRich.in_out
#
# Adding the following to the plot: Co_relaxed_ZnRich.in_out
