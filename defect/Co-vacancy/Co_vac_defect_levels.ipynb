# %%
import matplotlib.pyplot as plt

vbm = 5.5452
gap = 2.01

def extract_energies(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    start_line = "          k = 0.0000 0.0000 0.0000"
    end_line = "occupation numbers"
    fermi_line = "the Fermi energy is"
    energies = []

    start_reading = False
    for line in lines:
        if fermi_line in line:
            fermi = float(line.split()[-2])
        if end_line in line:
            start_reading = False
        if start_line in line:
            start_reading = True
            continue
        if start_reading:
            energies.extend([float(e) for e in line.split()])

    return energies, fermi

def plot_energy_levels(energies, xmin, xmax, fermi):
    for energy in energies:
        plt.hlines(y=energy-vbm, xmin=xmin, xmax=xmax, color='b')
    plt.hlines(y=fermi-vbm, xmin=xmin, xmax=xmax, color='r')
    plt.ylabel('Energy (eV)', fontsize=15)
    #plt.ylim(5, 8)
    plt.ylim(0-.5, gap+.5)

# %%
filename_qn2 = "relaxed/qn2/2.Co_vac_in_ZnS.scf.qn2.out"
energies_qn2, fermi_qn2 = extract_energies(filename_qn2)

filename_qn1 = "relaxed/qn1/2.Co_vac_in_ZnS.scf.qn1.out"
energies_qn1, fermi_qn1 = extract_energies(filename_qn1)

filename_q0 = "relaxed/q0/2.Co_vac_in_ZnS.scf.q0.out"
energies_q0, fermi_q0 = extract_energies(filename_q0)

filename_qp1 = "relaxed/qp1/2.Co_vac_in_ZnS.scf.qp1.out"
energies_qp1, fermi_qp1= extract_energies(filename_qp1)

filename_qp2 = "relaxed/qp2/2.Co_vac_in_ZnS.scf.qp2.out"
energies_qp2, fermi_qp2= extract_energies(filename_qp2)

plt.figure(figsize=(8,6))
plot_energy_levels(energies_qn2, 0, 1, fermi_qn2)
plot_energy_levels(energies_qn1, 1, 2, fermi_qn1)
plot_energy_levels(energies_q0, 2, 3, fermi_q0)
plot_energy_levels(energies_qp1, 3, 4, fermi_qp1)
plot_energy_levels(energies_qp2, 4, 5, fermi_qp2)

plt.title(r'Defect level diagram - relaxed ($k=\Gamma$)', fontsize=15)
plt.hlines(y=0, color='k', linewidth=2, xmin=0, xmax=5)
plt.hlines(y=gap, color='k', linewidth=2, xmin=0, xmax=5)
plt.xticks([0.5, 1.5, 2.5, 3.5, 4.5], [r'$(\mathrm{Co_{Zn}}$-$\mathrm{V_{S}})^{2-}$', r'$(\mathrm{Co_{Zn}}$-$\mathrm{V_{S}})^{1-}$', r'$(\mathrm{Co_{Zn}}$-$\mathrm{V_{S}})^{0}$', r'$(\mathrm{Co_{Zn}}$-$\mathrm{V_{S}})^{1+}$', r'$(\mathrm{Co_{Zn}}$-$\mathrm{V_{S}})^{2+}$'], fontsize=12)
plt.show()

# %%
filename_qn2 = "unrelaxed/qn2/1.Co_vac_in_ZnS.scf.qn2.unrlxd.out"
energies_qn2, fermi_qn2 = extract_energies(filename_qn2)

filename_qn1 = "unrelaxed/qn1/1.Co_vac_in_ZnS.scf.qn1.unrlxd.out"
energies_qn1, fermi_qn1 = extract_energies(filename_qn1)

filename_q0 = "unrelaxed/q0/1.Co_vac_in_ZnS.scf.q0.unrlxd.out"
energies_q0, fermi_q0 = extract_energies(filename_q0)

filename_qp1 = "unrelaxed/qp1/1.Co_vac_in_ZnS.scf.qp1.unrlxd.out"
energies_qp1, fermi_qp1 = extract_energies(filename_qp1)

filename_qp2 = "unrelaxed/qp2/1.Co_vac_in_ZnS.scf.qp2.unrlxd.out"
energies_qp2, fermi_qp2 = extract_energies(filename_qp2)

plt.figure(figsize=(8,6))
plot_energy_levels(energies_qn2, 0, 1, fermi_qn2)
plot_energy_levels(energies_qn1, 1, 2, fermi_qn1)
plot_energy_levels(energies_q0, 2, 3, fermi_q0)
plot_energy_levels(energies_qp1, 3, 4, fermi_qp1)
plot_energy_levels(energies_qp2, 4, 5, fermi_qp2)

plt.title(r'Defect level diagram - unrelaxed ($k=\Gamma$)', fontsize=15)
plt.hlines(y=0, color='k', linewidth=2, xmin=0, xmax=5)
plt.hlines(y=gap, color='k', linewidth=2, xmin=0, xmax=5)
plt.xticks([0.5, 1.5, 2.5, 3.5, 4.5], [r'$(\mathrm{Co_{Zn}}$-$\mathrm{V_{S}})^{2-}$', r'$(\mathrm{Co_{Zn}}$-$\mathrm{V_{S}})^{1-}$', r'$(\mathrm{Co_{Zn}}$-$\mathrm{V_{S}})^{0}$', r'$(\mathrm{Co_{Zn}}$-$\mathrm{V_{S}})^{1+}$', r'$(\mathrm{Co_{Zn}}$-$\mathrm{V_{S}})^{2+}$'], fontsize=12)
plt.show()
