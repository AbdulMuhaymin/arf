# %%
import matplotlib.pyplot as plt

vbm = 5.5452
gap = 2.01

def extract_energies(filename):
    with open(filename, 'r') as file:
        lines = file.readlines()

    start_line = "          k = 0.0000 0.0000 0.0000"
    end_line = "occupation numbers"
    fermi_line = "the Fermi energy is"
    energies = []

    start_reading = False
    for line in lines:
        if fermi_line in line:
            fermi = float(line.split()[-2])
        if end_line in line:
            start_reading = False
        if start_line in line:
            start_reading = True
            continue
        if start_reading:
            energies.extend([float(e) for e in line.split()])

    return energies, fermi

def plot_energy_levels(energies, xmin, xmax, fermi):
    for energy in energies:
        plt.hlines(y=energy-vbm, xmin=xmin, xmax=xmax, color='b')
    plt.hlines(y=fermi-vbm, xmin=xmin, xmax=xmax, color='r')
    plt.ylabel('Energy (eV)', fontsize=15)
    #plt.ylim(5, 8)
    plt.ylim(0-.5, gap+.5)

# %%
filename_qn1 = "qn1/4/1.Cu_vac_in_ZnS.relax.qn1.U.4.out"
energies_qn1, fermi_qn1 = extract_energies(filename_qn1)

filename_q0 = "q0/4/2.Cu_vac_in_ZnS.scf.q0.U.4.out"
energies_q0, fermi_q0 = extract_energies(filename_q0)

filename_qp1 = "qp1/4/1.Cu_vac_in_ZnS.relax.qp1.U.4.out"
energies_qp1, fermi_qp1= extract_energies(filename_qp1)

plot_energy_levels(energies_qn1, 0, 1, fermi_qn1)
plot_energy_levels(energies_q0, 1, 2, fermi_q0)
plot_energy_levels(energies_qp1, 2, 3, fermi_qp1)

plt.title(r'Defect level diagram - relaxed ($k=\Gamma$), U=4', fontsize=15)
plt.hlines(y=0, color='k', linewidth=2, xmin=0, xmax=3)
plt.hlines(y=gap, color='k', linewidth=2, xmin=0, xmax=3)
plt.xlim(0,3)
plt.xticks([0.5, 1.5, 2.5], [r'$(\mathrm{Cu_{Zn}}-\mathrm{V_{S}})^{1-}$', r'$(\mathrm{Cu_{Zn}}-\mathrm{V_{S}})^{0}$', r'$(\mathrm{Cu_{Zn}}-\mathrm{V_{S}})^{1+}$'], fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 12
#      10 plot_energy_levels(energies_qn1, 0, 1, fermi_qn1)
#      11 plot_energy_levels(energies_q0, 1, 2, fermi_q0)
# ---> 12 plot_energy_levels(energies_qp1, 2, 3, fermi_qp1)
#      14 plt.title(r'Defect level diagram - relaxed ($k=\Gamma$), U=4', fontsize=15)
#      15 plt.hlines(y=0, color='k', linewidth=2, xmin=0, xmax=3)
#
# Cell In[1], line 31, in plot_energy_levels(energies, xmin, xmax, fermi)
#      29 def plot_energy_levels(energies, xmin, xmax, fermi):
#      30     for energy in energies:
# ---> 31         plt.hlines(y=energy-vbm, xmin=xmin, xmax=xmax, color='b')
#      32     plt.hlines(y=fermi-vbm, xmin=xmin, xmax=xmax, color='r')
#      33     plt.ylabel('Energy (eV)', fontsize=15)
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/pyplot.py:3312, in hlines(y, xmin, xmax, colors, linestyles, label, data, **kwargs)
#    3300 @_copy_docstring_and_deprecators(Axes.hlines)
#    3301 def hlines(
#    3302     y: float | ArrayLike,
#    (...)
#    3310     **kwargs,
#    3311 ) -> LineCollection:
# -> 3312     return gca().hlines(
#    3313         y,
#    3314         xmin,
#    3315         xmax,
#    3316         colors=colors,
#    3317         linestyles=linestyles,
#    3318         label=label,
#    3319         **({"data": data} if data is not None else {}),
#    3320         **kwargs,
#    3321     )
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:1465, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1462 @functools.wraps(func)
#    1463 def inner(ax, *args, data=None, **kwargs):
#    1464     if data is None:
# -> 1465         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1467     bound = new_sig.bind(ax, *args, **kwargs)
#    1468     auto_label = (bound.arguments.get(label_namer)
#    1469                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:1123, in Axes.hlines(self, y, xmin, xmax, colors, linestyles, label, **kwargs)
#    1121     minx = np.nanmin(datalim.xmin)
#    1122     maxx = np.nanmax(datalim.xmax)
# -> 1123     miny = np.nanmin(datalim.ymin)
#    1124     maxy = np.nanmax(datalim.ymax)
#    1125 else:
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:356, in nanmin(a, axis, out, keepdims, initial, where)
#     354 # Check for all-NaN axis
#     355 kwargs.pop("initial", None)
# --> 356 mask = np.all(mask, axis=axis, **kwargs)
#     357 if np.any(mask):
#     358     res = _copyto(res, np.nan, mask)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:2504, in all(a, axis, out, keepdims, where)
#    2421 @array_function_dispatch(_all_dispatcher)
#    2422 def all(a, axis=None, out=None, keepdims=np._NoValue, *, where=np._NoValue):
#    2423     """
#    2424     Test whether all array elements along a given axis evaluate to True.
#    2425
#    (...)
#    2502
#    2503     """
# -> 2504     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#    2505                           keepdims=keepdims, where=where)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:86, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84             return reduction(axis=axis, dtype=dtype, out=out, **passkwargs)
#      85         else:
# ---> 86             return reduction(axis=axis, out=out, **passkwargs)
#      88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/core/_methods.py:64, in _all(a, axis, dtype, out, keepdims, where)
#      61 def _all(a, axis=None, dtype=None, out=None, keepdims=False, *, where=True):
#      62     # Parsing keyword arguments is currently fairly slow, so avoid it for now
#      63     if where is True:
# ---> 64         return umr_all(a, axis, dtype, out, keepdims)
#      65     return umr_all(a, axis, dtype, out, keepdims, where=where)
#
# KeyboardInterrupt:

# %%
filename_qn1 = "qn1/2/1.Cu_vac_in_ZnS.relax.qn1.U.2.out"
energies_qn1, fermi_qn1 = extract_energies(filename_qn1)

filename_q0 = "q0/2/2.Cu_vac_in_ZnS.scf.q0.U.2.out"
energies_q0, fermi_q0 = extract_energies(filename_q0)

filename_qp1 = "qp1/2/1.Cu_vac_in_ZnS.relax.qp1.U.2.out"
energies_qp1, fermi_qp1= extract_energies(filename_qp1)

plot_energy_levels(energies_qn1, 0, 1, fermi_qn1)
plot_energy_levels(energies_q0, 1, 2, fermi_q0)
plot_energy_levels(energies_qp1, 2, 3, fermi_qp1)

plt.title(r'Defect level diagram - relaxed ($k=\Gamma$), U=2', fontsize=15)
plt.hlines(y=0, color='k', linewidth=2, xmin=0, xmax=3)
plt.hlines(y=gap, color='k', linewidth=2, xmin=0, xmax=3)
plt.xlim(0,3)
plt.xticks([0.5, 1.5, 2.5], [r'$(\mathrm{Cu_{Zn}}-\mathrm{V_{S}})^{1-}$', r'$(\mathrm{Cu_{Zn}}-\mathrm{V_{S}})^{0}$', r'$(\mathrm{Cu_{Zn}}-\mathrm{V_{S}})^{1+}$'], fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 filename_qn1 = "qn1/1.Cu_vac_in_ZnS.relax.qn1.U.2.out"
# ----> 2 energies_qn1, fermi_qn1 = extract_energies(filename_qn1)
#       4 filename_q0 = "q0/2.Cu_vac_in_ZnS.scf.q0.U.2.out"
#       5 energies_q0, fermi_q0 = extract_energies(filename_q0)
#
# Cell In[1], line 7, in extract_energies(filename)
#       6 def extract_energies(filename):
# ----> 7     with open(filename, 'r') as file:
#       8         lines = file.readlines()
#      10     start_line = "          k = 0.0000 0.0000 0.0000"
#
# File ~/.local/lib/python3.10/site-packages/IPython/core/interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'qn1/1.Cu_vac_in_ZnS.relax.qn1.U.2.out'

# %%
filename_qn1 = "unrelaxed/qn1/1.Cu_vac_in_ZnS.scf.qn1.unrlxd.out"
energies_qn1, fermi_qn1 = extract_energies(filename_qn1)

filename_q0 = "unrelaxed/q0/1.Cu_vac_in_ZnS.scf.q0.unrlxd.out"
energies_q0, fermi_q0 = extract_energies(filename_q0)

filename_qp1 = "unrelaxed/qp1/1.Cu_vac_in_ZnS.scf.qp1.unrlxd.out"
energies_qp1, fermi_qp1 = extract_energies(filename_qp1)

plot_energy_levels(energies_qn1, 0, 1, fermi_qn1)
plot_energy_levels(energies_q0, 1, 2, fermi_q0)
plot_energy_levels(energies_qp1, 2, 3, fermi_qp1)

plt.title(r'Defect level diagram - unrelaxed ($k=\Gamma$)', fontsize=15)
plt.hlines(y=0, color='k', linewidth=2, xmin=0, xmax=3)
plt.hlines(y=gap, color='k', linewidth=2, xmin=0, xmax=3)
plt.xlim(0,3)
plt.xticks([0.5, 1.5, 2.5], [r'$(\mathrm{Cu_{Zn}}-\mathrm{V_{S}})^{1-}$', r'$(\mathrm{Cu_{Zn}}-\mathrm{V_{S}})^{0}$', r'$(\mathrm{Cu_{Zn}}-\mathrm{V_{S}})^{1+}$'], fontsize=15)
plt.show()
