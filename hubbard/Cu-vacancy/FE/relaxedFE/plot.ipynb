# %%
from dfe import *

# %%
calculate_E_formation('0.in')
calculate_E_formation('2.in')
calculate_E_formation('3.in')
calculate_E_formation('4.in')
# Out:
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5717.237574721784
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6618.3056898417835
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 6.147981258216532
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5717.947833119837
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6619.015948239837
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 5.437722860163376
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5719.884980848317
#
# chem_potential for S (vacancy)  has been added.
#
# ...

# %%
plot_multiple_formation_E("all.in", case="Relaxed, Cu-vacancy, Hubbard")
# Out:
# Adding the following to the plot: 0.in_out
#
# Adding the following to the plot: 2.in_out
#
# Adding the following to the plot: 3.in_out
#
# Adding the following to the plot: 4.in_out

# %%
plot_multiple_formation_E("all.in", case="Relaxed, Cu-vacancy, Hubbard")
# Out:
# Adding the following to the plot: 2.in_out
#
# Adding the following to the plot: 3.in_out
#
# Adding the following to the plot: 4.in_out
