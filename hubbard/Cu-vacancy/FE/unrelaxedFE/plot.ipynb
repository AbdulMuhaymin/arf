# %%
from dfe import *

# %%
calculate_E_formation('2.in')
calculate_E_formation('3.in')
calculate_E_formation('4.in')
calculate_E_formation('5.in')
calculate_E_formation('6.in')
calculate_E_formation('7.in')
calculate_E_formation('8.in')
# Out:
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5711.84104306239
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6612.90915818239
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 11.544512917610518
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5713.100122285998
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6614.168237405997
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 10.285433694002677
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5713.651731240344
#
# chem_potential for S (vacancy)  has been added.
#
# ...

# %%
calculate_E_formation('0.in')
# Out:
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5716.360428139752
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6617.428543259752
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 7.025127840248388
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5717.646438334024
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6618.714553454024
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 5.739117645975966
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5718.285876247999
#
# chem_potential for S (vacancy)  has been added.
#
# ...

# %%
plot_multiple_formation_E("all.in", case="Unrelaxed, Cu-vacancy, Hubbard")
# Out:
# Adding the following to the plot: 0.in_out
#
# Adding the following to the plot: 2.in_out
#
# Adding the following to the plot: 3.in_out
#
# Adding the following to the plot: 4.in_out
#
# Adding the following to the plot: 5.in_out
#
# Adding the following to the plot: 6.in_out
#
# Adding the following to the plot: 7.in_out
#
# Adding the following to the plot: 8.in_out

# %%
plot_multiple_formation_E("all.in", case="Unrelaxed, Cu-vacancy, Hubbard")
# Out:
# Adding the following to the plot: 2.in_out
#
# Adding the following to the plot: 3.in_out
#
# Adding the following to the plot: 4.in_out
#
# Adding the following to the plot: 5.in_out
#
# Adding the following to the plot: 6.in_out
#
# Adding the following to the plot: 7.in_out
#
# Adding the following to the plot: 8.in_out

# %%
calculate_E_formation('2.in')
# Out:
# charge_state =-1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5711.84104306239
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6612.90915818239
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 11.544512917610518
#
#
# charge_state =0
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5713.100122285998
#
# chem_potential for S (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -6614.168237405997
#
# chem_potential for Cu (impurity)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = 10.285433694002677
#
#
# charge_state =1
#
# chem_potential for Zn (vacancy)  has been added.
#
# Energy_part + q* VBM + chem_pot (so far) = -5713.651731240344
#
# chem_potential for S (vacancy)  has been added.
#
# ...
